# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
routes = pd.read_csv("../hk_gtfs/routes.txt")

# %%
trips = pd.read_csv("../hk_gtfs/trips.txt")

# %%
stop_times = pd.read_csv("../hk_gtfs/stop_times.txt")

# %%
stops = pd.read_csv("../hk_gtfs/stops.txt")

# %%
calendar = pd.read_csv("../hk_gtfs/calendar.txt")
calendar_dates = pd.read_csv("../hk_gtfs/calendar_dates.txt")

# %%
frequencies = pd.read_csv("../hk_gtfs/frequencies.txt")

# %%
print(routes.head())
# Out:
#    route_id agency_id route_short_name  \
# 0      1001       KMB                1
# 1      1002       KMB               10
# 2      1006   KMB+CTB             102P
# 3      1008   KMB+CTB              103
# 4      1010   KMB+CTB              106
#
#                               route_long_name  route_type  \
# 0               CHUK YUEN ESTATE - STAR FERRY           3
# 1          CHOI WAN - TAI KOK TSUI (CIRCULAR)           3
# 2                      SHAU KEI WAN - MEI FOO           3
# 3              CHUK YUEN ESTATE - POKFIELD RD           3
# 4  WONG TAI SIN - SIU SAI WAN (ISLAND RESORT)           3
#
#                                            route_url
# 0  https://search.kmb.hk/KMBWebSite/?action=route...
# 1  https://search.kmb.hk/KMBWebSite/?action=route...
# 2  https://search.kmb.hk/KMBWebSite/?action=route...
# 3  https://search.kmb.hk/KMBWebSite/?action=route...
# 4  https://search.kmb.hk/KMBWebSite/?action=route...

# %%
stops.head()
# Out:
#    stop_id                                          stop_name  stop_lat  \
# 0        2  [CTB] HIU TSUI STREET, SIU SAI WAN ROAD|[KMB+C...  22.26436
# 1        3  [CTB] FU SHING COURT, CHAI WAN ROAD|[KMB+CTB] ...  22.26578
# 2        4  [CTB] LOK HIN TERRACE, CHAI WAN ROAD|[KMB+CTB]...  22.26492
# 3        5  [CTB] WAN TSUI SHOPPING CENTRE, CHAI WAN ROAD|...  22.26312
# 4        6  [CTB] CHAK TSUI HOUSE WAN TSUI ESTATE, WAN TSU...  22.26242
#
#     stop_lon  zone_id  location_type   stop_timezone
# 0  114.24821        2              0  Asia/Hong_Kong
# 1  114.24542        3              0  Asia/Hong_Kong
# 2  114.24167        4              0  Asia/Hong_Kong
# 3  114.23875        5              0  Asia/Hong_Kong
# 4  114.23655        6              0  Asia/Hong_Kong

# %%
specific_routes = routes[(routes["route_short_name"] == "970") & (routes["agency_id"] != "NLB")]
specific_routes
# Out:
#       route_id agency_id route_short_name                     route_long_name  \
# 480       1665       CTB              970            CYBERPORT - SO UK ESTATE
# 1093      8715       CTB              970  CYBERPORT - MONG KOK (BUTE STREET)
#
#       route_type                                          route_url
# 480            3  https://mobile.citybus.com.hk/nwp3/?f=1&ds=970...
# 1093           3  https://mobile.citybus.com.hk/nwp3/?f=1&ds=970...

# %%
specific_trips = trips[trips["route_id"] == 1665]
print(specific_trips)
print(specific_trips.service_id.unique())
# Out:
#        route_id  service_id          trip_id
# 21145      1665         287  1665-1-287-0535
# 21146      1665         287  1665-1-287-0553
# 21147      1665         287  1665-1-287-0608
# 21148      1665         287  1665-1-287-0621
# 21149      1665         287  1665-1-287-0633
# ...         ...         ...              ...
# 21241      1665         448  1665-2-448-1007
# 21242      1665         448  1665-2-448-1252
# 21243      1665         448  1665-2-448-2152
# 21244      1665         448  1665-2-448-2237
# 21245      1665         448  1665-2-448-2413
#
# [101 rows x 3 columns]
# [287 288 448]

# %%
filtered_stoptimes = stop_times[stop_times["trip_id"] == "2002580-2-287-1000"]
filtered_stoptimes
# Out:
#                    trip_id arrival_time departure_time   stop_id  \
# 958053  2002580-2-287-1000     10:00:00       10:00:00  20009733
# 958054  2002580-2-287-1000          NaN            NaN  20000334
# 958055  2002580-2-287-1000          NaN            NaN  20009766
# 958056  2002580-2-287-1000          NaN            NaN  20004594
# 958057  2002580-2-287-1000          NaN            NaN  20009736
# 958058  2002580-2-287-1000          NaN            NaN  20007719
# 958059  2002580-2-287-1000          NaN            NaN  20002491
# 958060  2002580-2-287-1000          NaN            NaN  20002492
# 958061  2002580-2-287-1000          NaN            NaN  20004115
# 958062  2002580-2-287-1000          NaN            NaN  20000370
# 958063  2002580-2-287-1000     10:20:00       10:20:00  20000326
#
#         stop_sequence  pickup_type  drop_off_type  timepoint
# 958053              1            0              1          1
# 958054              2            0              0          0
# 958055              3            0              0          0
# 958056              4            0              0          0
# 958057              5            0              0          0
# 958058              6            0              0          0
# 958059              7            0              0          0
# 958060              8            0              0          0
# 958061              9            0              0          0
# 958062             10            0              0          0
# 958063             11            1              0          1

# %%
filtered_stops = filtered_stoptimes.merge(stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']], on='stop_id', how='left')
filtered_stops
# Out:
#                trip_id arrival_time departure_time   stop_id  stop_sequence  \
# 0   2002580-2-287-1000     10:00:00       10:00:00  20009733              1
# 1   2002580-2-287-1000          NaN            NaN  20000334              2
# 2   2002580-2-287-1000          NaN            NaN  20009766              3
# 3   2002580-2-287-1000          NaN            NaN  20004594              4
# 4   2002580-2-287-1000          NaN            NaN  20009736              5
# 5   2002580-2-287-1000          NaN            NaN  20007719              6
# 6   2002580-2-287-1000          NaN            NaN  20002491              7
# 7   2002580-2-287-1000          NaN            NaN  20002492              8
# 8   2002580-2-287-1000          NaN            NaN  20004115              9
# 9   2002580-2-287-1000          NaN            NaN  20000370             10
# 10  2002580-2-287-1000     10:20:00       10:20:00  20000326             11
#
#     pickup_type  drop_off_type  timepoint  \
# 0             0              1          1
# 1             0              0          0
# 2             0              0          0
# 3             0              0          0
# 4             0              0          0
# 5             0              0          0
# 6             0              0          0
# 7             0              0          0
# 8             0              0          0
# 9             0              0          0
# 10            1              0          1
#
#                                             stop_name  stop_lat   stop_lon
# 0                                KENNEDY TOWN STATION  22.28135  114.12893
# 1   VICTORIA ROAD, OPPOSITE ENGLISH SCHOOLS FOUNDA...  22.27322  114.12643
# 2   FUNG YIU KING HOSPITAL, SANDY BAY ROAD|SANDY B...  22.27186  114.12502
# 3   SHA WAN DRIVE, OUTSIDE MACLEHOSE MEDICAL REHAB...  22.26978  114.12387
# 4   THE LAYBY AT CYBERPORT ROAD OPPOSITE TO THE AR...  22.26147  114.13023
# 5                INFORMATION CRESCENT, CYBERPORT ROAD  22.26095  114.13142
# 6   CYBERPORT ROAD, OPPOSITE CYBERPORT 3|CYBERPORT...  22.25985  114.13254
# 7   BEL-AIR PHASE 2, CYPERPORT ROAD|CYPERPORT ROAD...  22.25667  114.13279
# 8   BEL-AIR ON THE PEAK, CYBERPORT ROAD|BEL-AIR ON...  22.25473  114.13364
# 9   SHEK PAI WAN ROAD, NEAR TIN WAN STREET|SHEK PA...  22.24935  114.14855
# 10             WU NAM STREET, OUTSIDE ON TAI BUILDING  22.24775  114.15558

# %%
#the service id is equal to the days of the week in binary lol
#287 = regular weekdays
#319 = Weekdays + Saturday
#288 = Saturday
#448 = Sunday
#Combinations: 287, 288, 448 or 319, 448
calendar[calendar.service_id == 448]
print(calendar_dates[calendar_dates.service_id == 448])
# Out:
#       service_id      date  exception_type
# 3808         448  20260101               1
# 3809         448  20260217               1
# 3810         448  20260218               1
# 3811         448  20260219               1
# 3812         448  20260403               1
# 3813         448  20260404               1
# 3814         448  20260406               1
# 3815         448  20260407               1
# 3816         448  20260501               1
# 3817         448  20260525               1
# 3818         448  20260619               1
# 3819         448  20260701               1
# 3820         448  20260926               1
# 3821         448  20261001               1
# 3822         448  20261019               1
# 3823         448  20261225               1
# 3824         448  20261226               1

# %%
frequencies[frequencies.trip_id == '2002580-2-287-1000']
# Out:
#                   trip_id start_time  end_time  headway_secs
# 43503  2002580-2-287-1000   10:00:00  16:00:00           480
