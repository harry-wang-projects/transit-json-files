# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
routes = pd.read_csv("../chicago_gtfs/routes.txt")

# %%
trips = pd.read_csv("../chicago_gtfs/trips.txt")

# %%
stop_times = pd.read_csv("../chicago_gtfs/stop_times.txt")

# %%
stops = pd.read_csv("../chicago_gtfs/stops.txt")

# %%
calendar = pd.read_csv("../chicago_gtfs/calendar.txt")
calendar_dates = pd.read_csv("../chicago_gtfs/calendar_dates.txt")

# %%
frequencies = pd.read_csv("../chicago_gtfs/frequencies.txt")

# %%
print(routes.head())
# Out:
#    agency_id route_id route_short_name            route_long_name  route_type  \
# 0      50066        1                1  Bronzeville/Union Station           3
# 1      50066        2                2          Hyde Park Express           3
# 2      50066        3                3                 King Drive           3
# 3      50066        4                4              Cottage Grove           3
# 4      50066       X4               X4      Cottage Grove Express           3
#
#                                route_url route_color route_text_color
# 0   http://www.transitchicago.com/bus/1/      99999C           ffffff
# 1   http://www.transitchicago.com/bus/2/      b71234           ffffff
# 2   http://www.transitchicago.com/bus/3/      99999C           ffffff
# 3   http://www.transitchicago.com/bus/4/      414145           ffffff
# 4  http://www.transitchicago.com/bus/X4/      b71234           ffffff

# %%
stops.head()
# Out:
#    stop_id  stop_code                  stop_name  \
# 0        1        1.0  Jackson & Austin Terminal
# 1        2        2.0             5900 W Jackson
# 2        4        4.0             5700 W Jackson
# 3        6        6.0            Jackson & Lotus
# 4        7        7.0             5351 W Jackson
#
#                                            stop_desc   stop_lat   stop_lon  \
# 0  Jackson & Austin Terminal, Northeastbound, Bus...  41.876330 -87.774111
# 1  5900 W Jackson, Eastbound, Southside of the St...  41.877075 -87.771324
# 2  5700 W Jackson, Eastbound, Southside of the St...  41.876992 -87.768264
# 3       Jackson & Lotus, Eastbound, Southeast Corner  41.876521 -87.761452
# 4  5351 W Jackson, Eastbound, Southside of the St...  41.876560 -87.758931
#
#    location_type  parent_station  wheelchair_boarding
# 0              0             NaN                    1
# 1              0             NaN                    1
# ...

# %%
specific_routes = routes[(routes["route_short_name"] == "4")]
specific_routes
# Out:
#    agency_id route_id route_short_name route_long_name  route_type  \
# 3      50066        4                4   Cottage Grove           3
#
#                               route_url route_color route_text_color
# 3  http://www.transitchicago.com/bus/4/      414145           ffffff

# %%
specific_trips = trips[trips["route_id"] == "4"]
print(specific_trips)
print(specific_trips.describe())
print(specific_trips.service_id.unique())
# Out:
#       route_id  service_id        trip_id  direction_id      block_id  \
# 29341        4       67801  6780000064020             0  678000002694
# 29342        4       67801  6780000535020             0  678000004297
# 29343        4       67801  6780000638020             0  678000002643
# 29344        4       67801  6780001034020             0  678000002693
# 29345        4       67801  6780002484020             0  678000002645
# ...        ...         ...            ...           ...           ...
# 30802        4       67915  6790002347010             1  679000004152
# 30803        4       67915  6790015535010             1  679000004146
# 30804        4       67915  6790025912010             1  679000004139
# 30805        4       67915  6790028937010             1  679000004145
# 30806        4       67915  6790030085010             1  679000004153
#
#        shape_id direction  wheelchair_accessible  schd_trip_id
# 29341  67819379     South                      1         64020
# ...

# %%
filtered_stoptimes = stop_times[stop_times["trip_id"] == 6780000064020]
filtered_stoptimes
# Out:
#               trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 130464  6780000064020     14:13:00       14:13:00     2530              1
# 130466  6780000064020     14:14:30       14:14:30    14222              2
# 130468  6780000064020     14:15:31       14:15:31    14224              3
# 130470  6780000064020     14:17:32       14:17:32     1104              4
# 130472  6780000064020     14:18:45       14:18:45     1105              5
# ...               ...          ...            ...      ...            ...
# 131050  6780000064020     15:47:07       15:47:07     2838            118
# 131051  6780000064020     15:47:54       15:47:54    15156            119
# 131052  6780000064020     15:48:42       15:48:42     2840            120
# 131053  6780000064020     15:49:18       15:49:18     2841            121
# 131054  6780000064020     15:50:00       15:50:00    18241            122
#
#        stop_headsign  pickup_type  shape_dist_traveled
# ...

# %%
filtered_stops = filtered_stoptimes.merge(stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']], on='stop_id', how='left')
filtered_stops
# Out:
#            trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0    6780000064020     14:13:00       14:13:00     2530              1
# 1    6780000064020     14:14:30       14:14:30    14222              2
# 2    6780000064020     14:15:31       14:15:31    14224              3
# 3    6780000064020     14:17:32       14:17:32     1104              4
# 4    6780000064020     14:18:45       14:18:45     1105              5
# ..             ...          ...            ...      ...            ...
# 117  6780000064020     15:47:07       15:47:07     2838            118
# 118  6780000064020     15:47:54       15:47:54    15156            119
# 119  6780000064020     15:48:42       15:48:42     2840            120
# 120  6780000064020     15:49:18       15:49:18     2841            121
# 121  6780000064020     15:50:00       15:50:00    18241            122
#
#     stop_headsign  pickup_type  shape_dist_traveled  \
# 0           115th            0                    0
# ...

# %%
#the service id is equal to the days of the week in binary lol
#287 = regular weekdays
#319 = Weekdays + Saturday
#288 = Saturday
#448 = Sunday
#Combinations: 287, 288, 448 or 319, 448
calendar[calendar.service_id == 448]
print(calendar_dates[calendar_dates.service_id == 448])
# Out:
#       service_id      date  exception_type
# 3808         448  20260101               1
# 3809         448  20260217               1
# 3810         448  20260218               1
# 3811         448  20260219               1
# 3812         448  20260403               1
# 3813         448  20260404               1
# 3814         448  20260406               1
# 3815         448  20260407               1
# 3816         448  20260501               1
# 3817         448  20260525               1
# 3818         448  20260619               1
# 3819         448  20260701               1
# 3820         448  20260926               1
# 3821         448  20261001               1
# 3822         448  20261019               1
# 3823         448  20261225               1
# 3824         448  20261226               1

# %%
frequencies[frequencies.trip_id == '2002580-2-287-1000']
# Out:
#                   trip_id start_time  end_time  headway_secs
# 43503  2002580-2-287-1000   10:00:00  16:00:00           480
