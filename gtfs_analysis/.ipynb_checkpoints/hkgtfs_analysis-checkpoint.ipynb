# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
routes = pd.read_csv("../hk_gtfs/routes.txt")

# %% [raw]
# trips = pd.read_csv("../hk_gtfs/trips.txt")

# %%
stop_times = pd.read_csv("../hk_gtfs/stop_times.txt")

# %%
stops = pd.read_csv("../hk_gtfs/stops.txt")

# %%
routes.head()
# Out:
#    route_id agency_id route_short_name  \
# 0      1001       KMB                1
# 1      1002       KMB               10
# 2      1006   KMB+CTB             102P
# 3      1008   KMB+CTB              103
# 4      1010   KMB+CTB              106
#
#                               route_long_name  route_type  \
# 0               CHUK YUEN ESTATE - STAR FERRY           3
# 1          CHOI WAN - TAI KOK TSUI (CIRCULAR)           3
# 2                      SHAU KEI WAN - MEI FOO           3
# 3              CHUK YUEN ESTATE - POKFIELD RD           3
# 4  WONG TAI SIN - SIU SAI WAN (ISLAND RESORT)           3
#
#                                            route_url
# 0  https://search.kmb.hk/KMBWebSite/?action=route...
# 1  https://search.kmb.hk/KMBWebSite/?action=route...
# 2  https://search.kmb.hk/KMBWebSite/?action=route...
# 3  https://search.kmb.hk/KMBWebSite/?action=route...
# 4  https://search.kmb.hk/KMBWebSite/?action=route...

# %%
stops.head()
# Out:
#    stop_id                                          stop_name  stop_lat  \
# 0        2  [CTB] HIU TSUI STREET, SIU SAI WAN ROAD|[KMB+C...  22.26436
# 1        3  [CTB] FU SHING COURT, CHAI WAN ROAD|[KMB+CTB] ...  22.26578
# 2        4  [CTB] LOK HIN TERRACE, CHAI WAN ROAD|[KMB+CTB]...  22.26492
# 3        5  [CTB] WAN TSUI SHOPPING CENTRE, CHAI WAN ROAD|...  22.26312
# 4        6  [CTB] CHAK TSUI HOUSE WAN TSUI ESTATE, WAN TSU...  22.26242
#
#     stop_lon  zone_id  location_type   stop_timezone
# 0  114.24821        2              0  Asia/Hong_Kong
# 1  114.24542        3              0  Asia/Hong_Kong
# 2  114.24167        4              0  Asia/Hong_Kong
# 3  114.23875        5              0  Asia/Hong_Kong
# 4  114.23655        6              0  Asia/Hong_Kong

# %%
specific_routes = routes[(routes["route_short_name"] == "30X") & (routes["agency_id"] != "NLB")]
specific_routes
# Out:
#       route_id agency_id route_short_name  \
# 172       1176       KMB              30X
# 589       1890       CTB              30X
# 956       8582       CTB              30X
# 1488   1000461       KMB              30X
#
#                                         route_long_name  route_type  \
# 172         TSUEN WAN (ALLWAY GARDENS) - WHAMPOA GARDEN           3
# 589                        CYBERPORT - ADMIRALTY (EAST)           3
# 956               CENTRAL (EXCHANGE SQUARE) - CYBERPORT           3
# 1488  WHAMPOA GARDEN - TSUEN WAN (ALLWAY GARDENS) (V...           3
#
#                                               route_url
# 172   https://search.kmb.hk/KMBWebSite/?action=route...
# 589   https://mobile.citybus.com.hk/nwp3/?f=1&ds=30X...
# 956   https://mobile.citybus.com.hk/nwp3/?f=1&ds=30X...
# 1488  https://search.kmb.hk/KMBWebSite/?action=route...

# %%
specific_trips = trips[trips["route_id"] == 1890]
specific_trips
# Out:
#        route_id  service_id          trip_id
# 29055      1890         319  1890-1-319-0640
# 29056      1890         319  1890-1-319-0710
# 29057      1890         319  1890-1-319-1930
# 29058      1890         319  1890-2-319-0710
# 29059      1890         319  1890-2-319-0740
# 29060      1890         319  1890-2-319-1940
# 29061      1890         448  1890-1-448-0700
# 29062      1890         448  1890-1-448-0730
# 29063      1890         448  1890-1-448-1930
# 29064      1890         448  1890-2-448-0730
# 29065      1890         448  1890-2-448-2030

# %%
filtered_stoptimes = stop_times[stop_times["trip_id"] == "1890-1-448-0700"]
filtered_stoptimes
# Out:
#                 trip_id arrival_time departure_time   stop_id  stop_sequence  \
# 655964  1890-1-448-0700     07:00:00       07:00:00     10370              1
# 655965  1890-1-448-0700          NaN            NaN     12575              2
# 655966  1890-1-448-0700          NaN            NaN     12477              3
# 655967  1890-1-448-0700          NaN            NaN     12479              4
# 655968  1890-1-448-0700          NaN            NaN     12578              5
# 655969  1890-1-448-0700          NaN            NaN       375              6
# 655970  1890-1-448-0700          NaN            NaN       341              7
# 655971  1890-1-448-0700          NaN            NaN       344              8
# 655972  1890-1-448-0700          NaN            NaN       345              9
# 655973  1890-1-448-0700          NaN            NaN       350             10
# 655974  1890-1-448-0700          NaN            NaN       241             11
# 655975  1890-1-448-0700          NaN            NaN      1441             12
# 655976  1890-1-448-0700          NaN            NaN       647             13
# 655977  1890-1-448-0700     07:32:00       07:32:00  10000286             14
#
#         pickup_type  drop_off_type  timepoint
# 655964            0              1          1
# 655965            0              0          0
# 655966            0              0          0
# 655967            0              0          0
# 655968            0              0          0
# 655969            0              0          0
# 655970            0              0          0
# 655971            0              0          0
# 655972            0              0          0
# 655973            0              0          0
# 655974            0              0          0
# 655975            0              0          0
# 655976            0              0          0
# 655977            1              0          1

# %%
filtered_stops = filtered_stoptimes.merge(stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']], on='stop_id', how='left')
filtered_stops
# Out:
#             trip_id arrival_time departure_time   stop_id  stop_sequence  \
# 0   1890-1-448-0700     07:00:00       07:00:00     10370              1
# 1   1890-1-448-0700          NaN            NaN     12575              2
# 2   1890-1-448-0700          NaN            NaN     12477              3
# 3   1890-1-448-0700          NaN            NaN     12479              4
# 4   1890-1-448-0700          NaN            NaN     12578              5
# 5   1890-1-448-0700          NaN            NaN       375              6
# 6   1890-1-448-0700          NaN            NaN       341              7
# 7   1890-1-448-0700          NaN            NaN       344              8
# 8   1890-1-448-0700          NaN            NaN       345              9
# 9   1890-1-448-0700          NaN            NaN       350             10
# 10  1890-1-448-0700          NaN            NaN       241             11
# 11  1890-1-448-0700          NaN            NaN      1441             12
# 12  1890-1-448-0700          NaN            NaN       647             13
# 13  1890-1-448-0700     07:32:00       07:32:00  10000286             14
#
#     pickup_type  drop_off_type  timepoint  \
# 0             0              1          1
# 1             0              0          0
# 2             0              0          0
# 3             0              0          0
# 4             0              0          0
# 5             0              0          0
# 6             0              0          0
# 7             0              0          0
# 8             0              0          0
# 9             0              0          0
# 10            0              0          0
# 11            0              0          0
# 12            0              0          0
# 13            1              0          1
#
#                                             stop_name  stop_lat   stop_lon
# 0   [CTB] CYBERPORT|[KMB+CTB] CYBERPORT BUS TERMIN...  22.26186  114.13032
# 1   [CTB] CYBERPORT 3, CYBERPORT ROAD|[KMB+CTB] CY...  22.25994  114.13244
# 2   [CTB] RESIDENCE BEL-AIR, CYBERPORT ROAD|[KMB+C...  22.25658  114.13277
# 3   [CTB] BEL-AIR ON THE PEAK, CYBERPORT ROAD|[KMB...  22.25483  114.13365
# 4   [CTB] WAH CHUI STREET, VICTORIA ROAD|[KMB+CTB]...  22.25506  114.13622
# 5   [CTB] YU CHUN KEUNG MEMORIAL COLLEGE NO.2, POK...  22.25599  114.13757
# 6           [CTB] POK FU LAM VILLAGE, POK FU LAM ROAD  22.26052  114.13618
# 7              [CTB] EBENEZER SCHOOL, POK FU LAM ROAD  22.26731  114.13196
# 8          [CTB] QUEEN MARY HOSPITAL, POK FU LAM ROAD  22.26899  114.13068
# 9        [CTB] HKU CENTENNIAL CAMPUS, POK FU LAM ROAD  22.28434  114.13481
# 10  [CTB] TWO INTERNATIONAL FINANCE CENTRE, MAN YI...  22.28476  114.15982
# 11  [CTB] CENTRAL (EXCHANGE SQUARE)|[KMB+CTB] EXCH...  22.28415  114.15771
# 12  [CTB] CITY HALL, CONNAUGHT ROAD CENTRAL|[KMB+C...  22.28195  114.16125
# 13                       [CTB] ADMIRALTY - MTR EXIT C  22.27915  114.16461
